# %% [markdown]
# # 0. 프로젝트: SentencePiece를 사용한 감정 분석

# %% [markdown]
# ![rubric.JPG](attachment:rubric.JPG)

# %% [markdown]
# SentencePiece를 사용해 감정 분석을 해보자.
#
# SentencePiece는 Google에서 제공하는 오픈소스 기반 Sentence Tokenizer/Detokenizer 로서, BPE와 unigram 2가지 subword 토크나이징 모델 중 하나를 선택해서 사용할 수 있도록 패키징한 것이다. 아래 링크의 페이지에서 상세한 내용을 파악할 수 있다.
# https://github.com/google/sentencepiece
# 위 페이지의 서두에서도 언급하고 있듯, SentencePiece는 딥러닝 자연어처리 모델의 앞부분에 사용할 목적으로 최적화되어 있는데, 최근 pretrained model들이 거의 대부분 SentencePiece를 tokenizer로 채용하면서 사실상 표준의 역할을 하고 있다.

# %%
import os, re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# !pip install sentencepiece
import sentencepiece as spm
# !pip install konlpy
import konlpy

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

from sklearn.model_selection import train_test_split

# %%
tf.random.set_seed(9)
np.random.seed(9)

# %%
env = os.getenv('HOME') + '/aiffel/sp_tokenizer/data'

# %% [markdown]
# # 1. 데이터 불러오기

# %% [markdown]
# https://github.com/e9t/nsmc/
# Naver sentiment movie corpus 데이터를 사용한다.

# %% [markdown]
# Each file is consisted of three columns: id, document, label
# - id: The review id, provieded by Naver
# - document: The actual review
# - label: The sentiment class of the review. (0: negative, 1: positive)
# - Columns are delimited with tabs (i.e., .tsv format; but the file extension is .txt for easy access for novices)
#
# 200K reviews in total
# - ratings.txt: All 200K reviews
# - ratings_test.txt: 50K reviews held out for testing
# - ratings_train.txt: 150K reviews for training

# %%
ratings_train = pd.read_table(env + '/ratings_train.txt')
ratings_test = pd.read_table(env + '/ratings_test.txt')

# %%
ratings_train.tail()
# Out:
#              id                         document  label
# 149995  6222902              인간이 문제지.. 소는 뭔죄인가..      0
# 149996  8549745                    평점이 너무 낮아서...      1
# 149997  9311800  이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998  2376369      청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999  9619869         한국 영화 최초로 수간하는 내용이 담긴 영화      0

# %%
ratings_test.head()
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %% [markdown]
# 원활한 학습을 위해 중복된 데이터를 제거하고 결측 데이터도 제거한다.

# %%
ratings_train = ratings_train.drop_duplicates(subset=['document']).dropna(how='any').reset_index(drop=True)
ratings_test = ratings_test.drop_duplicates(subset=['document']).dropna(how='any').reset_index(drop=True)

# %% [markdown]
# # 2. 코퍼스 분석하기

# %% [markdown]
# 편의를 위해 train 데이터와 test 데이터를 합칠 건데
# 그 전에 train 데이터과 test 데이터를 구분짓는 샘플의 특징(여기서는 id 변수)을 추출해서 기억해놓는다.

# %%
train_end_id = ratings_train.iloc[-1]['id']
print(train_end_id)
# Out:
# 9619869

# %%
ratings = pd.concat([ratings_train, ratings_test]).reset_index(drop=True)
ratings
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 195334   4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 195335   5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 195336   9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 195337   5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 195338   6070594                                         마무리는 또 왜이래      0
#
# [195339 rows x 3 columns]

# %% [markdown]
# NLP하기 위해서는 모든 문장들이 같은 길이를 가지고 있어야 하는데
# 적당한 길이로 자르지 않으면 짧은 문장들의 패딩이 많아져서 불필요한 계산 비용이 발생한다.
#
# 따라서 적당한 길이를 알아보기 위해 문장의 최단 길이, 최장 길이, 평균 길이 및 길이의 분포를 살펴보자.

# %%
def cal_sentence_length(raw):
    sen_lens = [len(sen) for sen in raw]

    print("문장의 최단 길이:", min(sen_lens))
    print("문장의 최장 길이:", max(sen_lens))
    print("문장의 평균 길이:", sum(sen_lens) // len(raw))

    sentence_length = np.zeros((max(sen_lens)), dtype=np.int)

    for i in range(max(sen_lens)):
        sentence_length[i] += sen_lens.count(i)

    plt.bar(range(max(sen_lens)), sentence_length, width=1.0)
    plt.title("Sentence Length Distribution")
    plt.show()

# %%
cal_sentence_length(ratings['document'])
# Out:
# 문장의 최단 길이: 1
# 문장의 최장 길이: 146
# 문장의 평균 길이: 35
# /tmp/ipykernel_5581/3097477280.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sentence_length = np.zeros((max(sen_lens)), dtype=np.int)

# %% [markdown]
# 우선 평균보다는 길고, 그래프가 급격히 얇아지는 구간에서 자를 필요가 있어보인다.
#
# 우선 문장 길이가 1인 데이터는 어떤 것들이 있는지 알아보자.

# %%
def check_sentence_with_length(raw, length):
    count = 0
    sen_list = []
    
    for sen in raw:
        if len(sen) == length:
            sen_list.append(sen)
            count += 1
            if count > 100:
                return sen_list

# %%
print(check_sentence_with_length(ratings['document'], 3))
# Out:
# ['좋구나', '10점', '처ㅝ주', '솔직히', '4대강', '재밌다', '재밌군', '좋았다', '재미무', '보지마', '볼만함', 'b b', 'dsa', '웃스!', '♥♥♥', '재밋네', '최고다', '재밌음', '쓰래기', '갑이다', '료코짱', '2빠닼', '만세-', 'OOO', 'ㅋㅋㅋ', '아하!', '재및음', '좋아여', '재미쪙', '대박!', '에혀~', '3.6', '가보자', 'bad', '신선함', '와우!', '즐ㄹㅋ', '좋아요', '아ㅅㅂ', '쨩이야', '굿~!', 'ㅉㅉㅉ', '재밋다', '지못미', '나이스', '오짱!', '전형적', '원주율', '좋은테', '2.6', '굿!!', '1등?', '보세요', '잼없다', '다섯개', '접어라', '쓰중쓰', '좋다.', '음..', '좋군.', '싸우자', '멋져.', '...', '직인다', '짱짱짱', '별로임', '진리임', '감동적', '최고!', '재밌어', '걍 굿', '아시바', '최고~', '팬이다', '별로다', '좋다,', '잼있다', '최고.', '감동!', '잠온다', '의리!', '별로~', '즐..', '썩었내', '짱멋짐', 'ㄴㄹㄴ', '성룡짱', '꿀잼♥', '쵝오!', '괜찮네', '막장.', '억지.', '김서울', '철규찡', '무셔움', '지겨워', '꼭보셈', '쓰레기', '그다지', '훌륭함', '최고임']

# %%
print(check_sentence_with_length(ratings['document'], 4))
# Out:
# ['재밋는뎅', '킬링타임', '별로다.', '볼만해;', '연기 굿', '좋은영화', '굿 좋아', '재밌는데', '와...', '펑점조절', '싸우자!', '최고!!', '패륜영화', '어휴..', '재밌다.', '괜히봤다', '재미없음', '지루하다', '재미없다', '장난치냐', 'OOO기', '몰떡몰떡', 'good', '이건뭥미', '잼슴ㅇㅎ', '죽을래?', '짠하네요', '기대된디', '보고싶다', '나도별로', '추억돋네', '재밌어요', '야동!!', '왜봣지?', '볼만했음', '별로;;', '평점조절', '심하네.', '별로네요', '돈아깝다', '별10개', '최고다.', '어이없다', '별루 .', '굿입니당', '옥빈님짱', '언제꺼임', '-_-^', '뭐냐이게', '개쩔었다', '그지같다', '안무섭다', '푹 잤음', '재밌네요', '괜찬았음', '안과 겉', '참쩔어요', '재 밌다', '별론데?', '괜찬군요', '최고지~', '걍 평작', '명작이다', '재밋구만', '공블리짱', '잼나ㅎㅎ', '""""', '으하하하', '그만하자', '별로..', '...굿', '이건멍미', '재밌다!', '보영누나', '달달..', '허술하다', '넘잼있음', '재미있다', '좋았어요', '재밋어여', '씹쓰레기', '선동영화', '별로 ㅋ', '레전드.', '애절하다', '이연걸~', '재미없엉', '재미있음', '넘 잼따', '적절하다', '쩝...', '안습..', '지루력!', '최고였다', '훈훈하다', '뭘봐!!', '재밌던데', '쒸레기~', '최고이지', '의리다.', '쓰렉이얌']

# %% [markdown]
# 길이가 4인 문장부터는 거의 완전히 호불호가 드러난 것으로 보인다.
#
# 최대 길이를 50 이상으로 잡아서 대부분의 데이터를 살리면서도
# 그 중에 가장 작은 2의 거듭제곱인 64를 선택해서 패딩을 최소한으로 하겠다.

# %%
# point
min_len = 2 ** 2
max_len = 2 ** 6

# %%
# 길이 조건에 맞는 문장만 선택합니다.
ratings = ratings[ratings['document'].apply(lambda x: min_len <= len(x) <= max_len)]
print("Data Size:", len(ratings))
# Out:
# Data Size: 168532

# %%
print(f'잘린 길이 비율: {(146 - 64) / 146 * 100:.2f}%')
print(f'삭제한 데이터 비율: {(195339-168532) / 195339 * 100:.2f}%')
# Out:
# 잘린 길이 비율: 56.16%
# 삭제한 데이터 비율: 13.72%

# %% [markdown]
# 길이를 56%나 줄였지만 데이터는 13%밖에 삭제되지 않았다.

# %%
cal_sentence_length(ratings['document'])
# Out:
# 문장의 최단 길이: 4
# 문장의 최장 길이: 64
# 문장의 평균 길이: 26
# /tmp/ipykernel_5581/3097477280.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sentence_length = np.zeros((max(sen_lens)), dtype=np.int)

# %%
ratings
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 195334   4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 195335   5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 195336   9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 195337   5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 195338   6070594                                         마무리는 또 왜이래      0
#
# [168532 rows x 3 columns]

# %% [markdown]
# # 3. 전처리하기

# %% [markdown]
# 기본적인 문장 전처리를 해보자.

# %%
# 전처리 함수
def preprocess_sentence(sentence):
    # 로마자를 전부 소문자로 바꿉니다.
    sentence = sentence.lower()
    # 단어와 구두점(punctuation) 사이의 거리를 만듭니다.
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    # (a-z, A-Z, ㄱ-ㅣ, 가-힣, 0-9, ".", "?", "!", ",")를 제외한 모든 문자를 공백인 ' '로 대체합니다.
    sentence = re.sub(r"[^a-zA-Zㄱ-ㅣ가-힣0-9?.!,]+", " ", sentence)
    sentence = sentence.strip()
    
    return sentence

# %%
preprocess_sentence('  ㄱ     A         B    ㅗ    ')
# Out:
# 'ㄱ a b ㅗ'

# %%
ratings['document'] = ratings['document'].apply(preprocess_sentence)
ratings.head()
# Out:
# /tmp/ipykernel_5581/2981830919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings['document'] = ratings['document'].apply(preprocess_sentence)
#          id                                           document  label
# 0   9976970                              아 더빙 . . 진짜 짜증나네요 목소리      0
# 1   3819312         흠 . . . 포스터보고 초딩영화줄 . . . . 오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                 교도소 이야기구먼 . . 솔직히 재미는 없다 . . 평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화 ! 스파이더맨에서 늙어보이기만 했던 커스...      1

# %%
ratings.isna().sum()
# Out:
# id          0
# document    0
# label       0
# dtype: int64

# %% [markdown]
# 전처리로 인해 결측치로 변해버린 데이터는 없었다.

# %% [markdown]
# # 4. SentencePiece의 unigram 모델 사용하기

# %% [markdown]
# SentencePiece는 공백 기반도, 형태소 기반도 아닌 서브워드 기반 토크나이저이다.
# 서브워드는 예시로 보는 것이 가장 이해하기 쉽다.
# i am a boy and you are a girl
# 라는 문장을 각 알파벳별로 나누고 가능도가 높은 문자 쌍으로 합친
# [_i, _am, _a, _b, o, y, _a, n, d, _you, _are, _a, _gir, l]
# 토큰들로 나눴을 때 각 토큰이 서브워드인 것이다.

# %% [markdown]
# 우선 Unigram 모델을 사용할 건데 BPE와의 차이점은 아래와 같다.
#
# BPE: 사전에 정의한 vocabulary size에 도달하기 전까지 매 iteration마다 단지 등장 빈도수만을 확인하여 가장 많이 등장한 pair를 subword set에 추가한다.
# Unigram: 등장 빈도수는 전혀 사용하지 않고오직 확률모델을 사용한다. 대신 확률 모델을 사용하여 language Model을 훈련시킨다. 가장 적게 전반적인 likelihood를 개선한 token들을 삭제하고 final token limit을 만날 때까지 계속한다.

# %% [markdown]
# 우선 corpus를 텍스트 파일로 저장하고
# 그 파일에 센텐스피스 토크나이저를 수행하면
# 모델과 단어사전을 파일로 저장시켜준다.
# 신기한 점은 프로세서 인스턴스를 생성하고 퍼래머더를 지정하는 방식이 아닌
# 라이브러리로 바로 학습을 시키고 파일로 저장시킨 후 파일을 불러오는 방식인 것으로 보인다.
# 따라서 다른 퍼래머더를 적용시키려면 또 모델 파일을 생성해야한다.

# %%
temp_file = env + '/ratings.txt.temp'

with open(temp_file, 'w') as f:
    for row in ratings['document']:   # 이전 스텝에서 정제했던 corpus를 활용합니다.
        f.write(str(row) + '\n')
        
model_type = 'unigram'
spm.SentencePieceTrainer.Train('--input={} --model_prefix=korean_spm --model_type={}'.format(temp_file, model_type))

#위 Train에서  --model_type = 'unigram'이 디폴트 적용되어 있습니다. --model_type = 'bpe' 로 옵션을 주어 변경할 수 있습니다.

# !ls -l korean_spm*
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/sp_tokenizer/data/ratings.txt.temp --model_prefix=korean_spm --model_type=unigram
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/sp_tokenizer/data/ratings.txt.temp
#   input_format:
#   model_prefix: korean_spm
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/sp_tokenizer/data/ratings.txt.temp
# trainer_interface.cc(385) LOG(INFO) Loaded all 168510 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=4922717
# trainer_interface.cc(477) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1572
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 168510 sentences.
# unigram_model_trainer.cc(139) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(143) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(194) LOG(INFO) Initialized 251343 seed sentencepieces
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 168510
# trainer_interface.cc(537) LOG(INFO) Done! 249441
# unigram_model_trainer.cc(489) LOG(INFO) Using 249441 sentences for EM training
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=126310 obj=11.5508 num_tokens=514379 num_tokens/piece=4.07235
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=115259 obj=10.5782 num_tokens=516108 num_tokens/piece=4.47781
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=86404 obj=10.6255 num_tokens=541830 num_tokens/piece=6.27089
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=86250 obj=10.5862 num_tokens=542094 num_tokens/piece=6.28515
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=64680 obj=10.7478 num_tokens=574307 num_tokens/piece=8.87921
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=64672 obj=10.7045 num_tokens=574343 num_tokens/piece=8.88086
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=48504 obj=10.8926 num_tokens=605940 num_tokens/piece=12.4926
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=48504 obj=10.8488 num_tokens=605998 num_tokens/piece=12.4938
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=36377 obj=11.0618 num_tokens=639253 num_tokens/piece=17.573
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=36377 obj=11.0156 num_tokens=639246 num_tokens/piece=17.5728
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=27282 obj=11.256 num_tokens=673355 num_tokens/piece=24.6813
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=27282 obj=11.2068 num_tokens=673362 num_tokens/piece=24.6815
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=20461 obj=11.4771 num_tokens=708636 num_tokens/piece=34.6335
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=20461 obj=11.4228 num_tokens=708640 num_tokens/piece=34.6337
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=15345 obj=11.7172 num_tokens=745191 num_tokens/piece=48.5625
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=15345 obj=11.656 num_tokens=745203 num_tokens/piece=48.5632
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=11508 obj=11.9822 num_tokens=784320 num_tokens/piece=68.1543
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=11508 obj=11.9071 num_tokens=784336 num_tokens/piece=68.1557
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=8800 obj=12.2502 num_tokens=822864 num_tokens/piece=93.5073
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=8800 obj=12.1779 num_tokens=822869 num_tokens/piece=93.5078
# trainer_interface.cc(615) LOG(INFO) Saving model: korean_spm.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: korean_spm.vocab
# -rw-r--r-- 1 root root 377797 Nov 28 04:51 korean_spm.model
# -rw-r--r-- 1 root root 147285 Nov 28 04:51 korean_spm.vocab

# %% [markdown]
# 학습된 파일을 로드한 후 학습이 잘 되었는지 확인하기 위한 예시를 보자.

# %%
spp = spm.SentencePieceProcessor()
spp.Load('korean_spm.model')

# SentencePiece를 활용한 sentence -> encoding
tokensIDs = spp.EncodeAsIds('아버지가방에들어가신다.')
print(tokensIDs)

# SentencePiece를 활용한 sentence -> encoded pieces
print(spp.SampleEncodeAsPieces('아버지가방에들어가신다.', 1, 0.0))

# SentencePiece를 활용한 encoding -> sentence 복원
print(spp.DecodeIds(tokensIDs))
# Out:
# [1458, 11, 460, 15, 1365, 11, 167, 16, 7999]
# ['▁아버지', '가', '방', '에', '들어', '가', '신', '다', '.']
# 아버지가방에들어가신다.

# %% [markdown]
# EncodeAsIds 메소드는 정수 토큰을 불러온다.
# SampleEncodeAsPieces 메소드는 텍스트 토큰을 불러온다.
# DecodeIds 메소드는 텍스트 토큰을 합쳐서 보여준다.(사실상 원본)

# %% [markdown]
# # 5. Tokenizer 함수 작성하기

# %% [markdown]
# word_to_index, index_to_word 사전을 만들고
# 학습을 위해 패딩을 붙여보자.
# 단, korean_spm.vocab 파일에는 pad 토큰이 없어서
# 0번 인덱스가 \<unk>이므로 한 칸씩 뒤로 당긴 후
# 0번 인덱스가 \<pad>가 되게끔 만들어준다.

# %%
def sp_tokenize(spp, corpus):

    tensor = []

    for sen in corpus:
        tensor.append(list(map(lambda x: x+1, spp.EncodeAsIds(sen))))

    with open("./korean_spm.vocab", 'r') as f:
        vocab = f.readlines()

    word_index = {'<pad>': 0}
    index_word = {0: '<pad>'}

    for idx, line in enumerate(vocab):
        word = line.split("\t")[0]

        word_index.update({word:idx+1})
        index_word.update({idx+1:word})

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

    return tensor, word_index, index_word

# %%
#sp_tokenize(spp, corpus) 사용예제

my_corpus = ['나는 밥을 먹었습니다.', '그러나 여전히 ㅠㅠ 배가 고픕니다...']
print(sp_tokenize(spp, my_corpus)[0])
# Out:
# [[ 475 2990   15 1242 2661 8000    0    0    0    0    0    0]
#  [1238 1987  143  533   12    5   18 7921  706 8000 8000 8000]]

# %% [markdown]
# 모델에 적용시킬 X 데이터를 생성.

# %%
ratings_X, word_index, index_word = sp_tokenize(spp, ratings['document'])

# %%
print(ratings_X.shape)
ratings_X
# Out:
# (168532, 60)
# array([[  42,  911,    4, ...,    0,    0,    0],
#        [1212,    4,    4, ...,    0,    0,    0],
#        [  21,  485, 7810, ...,    0,    0,    0],
#        ...,
#        [1937,   13,  577, ...,    0,    0,    0],
#        [ 553, 1305,   14, ...,    0,    0,    0],
#        [1779,   14,  193, ...,    0,    0,    0]], dtype=int32)

# %%
vocab_size = len(word_index) # 단어의 수
vocab_size
# Out:
# 8001

# %% [markdown]
# 단어사전 크기는 8000(센텐스피스 기본값) + 1(pad) = 8001이다.

# %% [markdown]
# 센텐스피스가 적용된 실제 데이터를 몇개 살펴보자.

# %%
for i, tokens in enumerate(ratings_X[: 5]):
    print([index_word[token] for token in tokens if index_word[token] not in ['<pad>', '<unk>']])
    print(ratings['label'].iloc[i])
# Out:
# ['▁아', '▁더빙', '▁.', '▁.', '▁진짜', '▁짜증나', '네요', '▁목소리']
# 0
# ['▁흠', '▁.', '▁.', '▁.', '▁포스터', '보고', '▁초딩', '영화', '줄', '▁.', '▁.', '▁.', '▁.', '▁오버', '연기', '조차', '▁가볍', '지', '▁않', '구나']
# 1
# ['▁너무', '재', '밓', '었다', '그래', '서', '보는', '것을', '추천', '한다']
# 0
# ['▁교', '도', '소', '▁이야기', '구먼', '▁.', '▁.', '▁솔직히', '▁재미는', '▁없다', '▁.', '▁.', '▁평점', '▁조정']
# 0
# ['▁사이', '몬', '페', '그', '의', '▁', '익', '살', '스런', '▁연기가', '▁돋보였', '던', '▁영화', '▁!', '▁스파이더맨', '에서', '▁늙어', '보이', '기만', '▁했던', '▁커', '스틴', '▁', '던', '스트', '가', '▁너무나도', '▁이뻐', '보', '였다']
# 1

# %% [markdown]
# 다시 훈련 데이터와 평가 데이터를 나누기 위해 train_end_id를 가진 데이터의 인덱스를 추출한다.

# %%
train_end_idx = np.array(range(len(ratings)))[ratings['id'] == train_end_id][0]

train_end_idx
# Out:
# 126229

# %%
ratings.iloc[train_end_idx]
# Out:
# id                           9619869
# document    한국 영화 최초로 수간하는 내용이 담긴 영화
# label                              0
# Name: 146181, dtype: object

# %% [markdown]
# 아까 그 훈련 데이터의 마지막 데이터가 맞다.

# %%
train_X = ratings_X[: train_end_idx+1]
test_X = ratings_X[train_end_idx+1: ]

train_y = np.array(ratings['label'][: train_end_idx+1], dtype='float32')
test_y = np.array(ratings['label'][train_end_idx+1: ], dtype='float32')

# %%
print(train_X.shape)
print(test_X.shape)

print(train_y.shape)
print(test_y.shape)
# Out:
# (126230, 60)
# (42302, 60)
# (126230,)
# (42302,)

# %% [markdown]
# # 6. validation set 구성 및 모델 구성

# %% [markdown]
# 훈련 상태을 확인하기 위한 검증 데이터를 훈련 데이터에서 분할한다.

# %%
def tsize(train_X):
    length = len(train_X)
    return round(0.14 * (1 + length / 10 ** 4) ** (10 ** 4 / length) - 0.13, 2)

tsize(train_X)
# Out:
# 0.04

# %% [markdown]
# 훈련 데이터가 많아서 검증 데이터를 4%만 분할해도 괜찮을 것 같다.

# %%
X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size=tsize(train_X))

# %%
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (121180, 60)
# (5050, 60)
# (121180,)
# (5050,)

# %% [markdown]
# 간단한 LSTM 모델 생성.

# %%
# point
class model_maker(tf.keras.Model):
    def __init__(self, vocab_size, word_vector_dim, units):
        super().__init__()
        self.embedding1 = layers.Embedding(vocab_size, word_vector_dim, input_shape=(None, ))
        self.lstm1 = layers.Bidirectional(layers.LSTM(units))
        self.drop1 = layers.Dropout(0.5)
        self.dense2 = layers.Dense(1, activation='sigmoid')
        
    def call(self, x):
        x = self.embedding1(x)
        x = self.lstm1(x)
        x = self.drop1(x)
        x = self.dense2(x)
        
        return x

# %%
# point
word_vector_dim = 2 ** 6
units = int(word_vector_dim / 2)

model = model_maker(vocab_size, word_vector_dim, units)

# %% [markdown]
# # 7. 모델 훈련하기

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
              
epochs = 2 ** 4

early_stop = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

history = model.fit(X_train,
                    y_train,
                    epochs=epochs,
                    batch_size=2**10, # point
                    validation_data=(X_val, y_val),
                    verbose=1,
                   callbacks=[early_stop])
# Out:
# Epoch 1/16
# 119/119 [==============================] - 7s 20ms/step - loss: 0.5403 - accuracy: 0.7232 - val_loss: 0.3825 - val_accuracy: 0.8360
# Epoch 2/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3519 - accuracy: 0.8546 - val_loss: 0.3457 - val_accuracy: 0.8501
# Epoch 3/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3184 - accuracy: 0.8675 - val_loss: 0.3429 - val_accuracy: 0.8533
# Epoch 4/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3002 - accuracy: 0.8741 - val_loss: 0.3392 - val_accuracy: 0.8531
# Epoch 5/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2855 - accuracy: 0.8805 - val_loss: 0.3468 - val_accuracy: 0.8552
# Epoch 6/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2707 - accuracy: 0.8864 - val_loss: 0.3586 - val_accuracy: 0.8549
# Epoch 7/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2567 - accuracy: 0.8927 - val_loss: 0.3751 - val_accuracy: 0.8483
# Epoch 00007: early stopping

# %%
def history_plot(history):
    y_acc = history.history['accuracy']
    y_vacc = history.history['val_accuracy']
    
    y_loss = history.history['loss']
    y_vloss = history.history['val_loss']

    epochs_range = range(len(y_acc))

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, y_acc, marker='.', label="Train-set accuracy")
    plt.plot(epochs_range, y_vacc, marker='.', label="Validation-set accuracy")
    plt.legend(loc='lower right')
    plt.grid()
    plt.ylim(0.5, 1) 
    plt.title('Accurcy graph with batch normalization') 
    plt.xlabel('epoch')
    plt.ylabel('accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, y_loss, marker='.', label="Train-set Loss")
    plt.plot(epochs_range, y_vloss, marker='.', label="Validation-set Loss")
    plt.legend(loc='upper right')
    plt.grid()
    plt.title('Loss graph with batch normalization') 
    plt.xlabel('epoch')
    plt.ylabel('loss')
    
    plt.show()

# %%
history_plot(history)

# %%
result = model.evaluate(test_X, test_y, verbose=1)
# Out:
# 1322/1322 [==============================] - 5s 4ms/step - loss: 0.3797 - accuracy: 0.8454

# %% [markdown]
# # 8. SentencePiece의 BPE 모델 사용하기

# %% [markdown]
# 이번에는 bpe 모델을 사용해서 unigram과의 성능 차이를 확인해 보겠다.

# %%
model_type = 'bpe'
spm.SentencePieceTrainer.Train('--input={} --model_prefix=korean_spm --model_type={}'.format(temp_file, model_type))

#위 Train에서  --model_type = 'unigram'이 디폴트 적용되어 있습니다. --model_type = 'bpe' 로 옵션을 주어 변경할 수 있습니다.

# !ls -l korean_spm*
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/sp_tokenizer/data/ratings.txt.temp --model_prefix=korean_spm --model_type=bpe
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/sp_tokenizer/data/ratings.txt.temp
#   input_format:
#   model_prefix: korean_spm
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/sp_tokenizer/data/ratings.txt.temp
# trainer_interface.cc(385) LOG(INFO) Loaded all 168510 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=4922717
# trainer_interface.cc(477) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1572
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 168510 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 168510
# trainer_interface.cc(537) LOG(INFO) Done! 249441
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=227104 min_freq=82
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10444 size=20 all=100705 active=9316 piece=▁진
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7665 size=40 all=103711 active=12322 piece=▁있
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5557 size=60 all=108175 active=16786 piece=▁평점
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4481 size=80 all=112001 active=20612 piece=라마
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3685 size=100 all=114062 active=22673 piece=▁자
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=3661 min_freq=67
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3306 size=120 all=117682 active=9164 piece=▁비
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2741 size=140 all=119873 active=11355 piece=▁사랑
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2524 size=160 all=122136 active=13618 piece=면서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2286 size=180 all=124321 active=15803 piece=입니다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2094 size=200 all=126408 active=17890 piece=oo
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2077 min_freq=59
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1937 size=220 all=128971 active=8856 piece=야기
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1808 size=240 all=130987 active=10872 piece=▁이렇게
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1637 size=260 all=132726 active=12611 piece=▁초
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1539 size=280 all=134508 active=14392 piece=▁꼭
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1445 size=300 all=136487 active=16371 piece=부터
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1443 min_freq=53
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1359 size=320 all=138594 active=8698 piece=없다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1256 size=340 all=141303 active=11407 piece=▁망
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1185 size=360 all=143399 active=13503 piece=▁이상
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1139 size=380 all=144915 active=15019 piece=▁그리고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1095 size=400 all=146184 active=16288 piece=▁8
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1095 min_freq=49
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1058 size=420 all=148081 active=9197 piece=는다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=999 size=440 all=149875 active=10991 piece=하면
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=958 size=460 all=151714 active=12830 piece=▁이제
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=913 size=480 all=153207 active=14323 piece=▁새
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=879 size=500 all=154699 active=15815 piece=▁순
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=879 min_freq=45
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=847 size=520 all=155805 active=8801 piece=점도
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=808 size=540 all=157658 active=10654 piece=▁모두
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=775 size=560 all=159330 active=12326 piece=때문에
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=748 size=580 all=161411 active=14407 piece=봤는데
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=731 size=600 all=162771 active=15767 piece=▁아니다
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=729 min_freq=41
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=708 size=620 all=164253 active=9609 piece=▁캐릭터
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=689 size=640 all=165517 active=10873 piece=이는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=662 size=660 all=167008 active=12364 piece=▁강추
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=637 size=680 all=168885 active=14241 piece=이네
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=619 size=700 all=170611 active=15967 piece=▁수작
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=618 min_freq=39
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=607 size=720 all=171930 active=9822 piece=진다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=593 size=740 all=173101 active=10993 piece=▁그저
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=576 size=760 all=173859 active=11751 piece=▁재미가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=563 size=780 all=175009 active=12901 piece=만큼
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=552 size=800 all=176447 active=14339 piece=스러운
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=552 min_freq=37
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=541 size=820 all=177636 active=9881 piece=들을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=529 size=840 all=179346 active=11591 piece=▁각
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=516 size=860 all=180674 active=12919 piece=내용
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=506 size=880 all=182098 active=14343 piece=▁양
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=493 size=900 all=183300 active=15545 piece=▁된
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=493 min_freq=35
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=484 size=920 all=184555 active=10399 piece=▁우리나라
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=470 size=940 all=185547 active=11391 piece=▁극장에서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=456 size=960 all=186759 active=12603 piece=▁d
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=444 size=980 all=188310 active=14154 piece=▁암
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=432 size=1000 all=189506 active=15350 piece=만든
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=432 min_freq=33
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=422 size=1020 all=191047 active=10919 piece=▁영화네요
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=409 size=1040 all=192162 active=12034 piece=▁어떤
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=401 size=1060 all=193252 active=13124 piece=▁병
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=394 size=1080 all=194016 active=13888 piece=▁빠져
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=384 size=1100 all=194648 active=14520 piece=▁여주인공
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=383 min_freq=31
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=374 size=1120 all=195774 active=10820 piece=▁이름
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=368 size=1140 all=197043 active=12089 piece=▁생각보다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=358 size=1160 all=197742 active=12788 piece=▁얘
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=354 size=1180 all=198665 active=13711 piece=▁영상미
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=348 size=1200 all=199563 active=14609 piece=▁영화관에서
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=347 min_freq=30
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=339 size=1220 all=200600 active=10999 piece=땜에
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=333 size=1240 all=201850 active=12249 piece=▁말도
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=324 size=1260 all=202789 active=13188 piece=자체
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=318 size=1280 all=203567 active=13966 piece=해라
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=312 size=1300 all=204798 active=15197 piece=▁철
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=311 min_freq=29
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=301 size=1320 all=205708 active=11107 piece=▁다운
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=298 size=1340 all=206615 active=12014 piece=▁위해
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=293 size=1360 all=207960 active=13359 piece=▁봤음
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=289 size=1380 all=208526 active=13925 piece=영화다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=285 size=1400 all=209581 active=14980 piece=▁온
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=285 min_freq=28
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=281 size=1420 all=210795 active=11648 piece=▁어릴때
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=274 size=1440 all=211893 active=12746 piece=▁필
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=270 size=1460 all=212845 active=13698 piece=했어요
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=264 size=1480 all=213893 active=14746 piece=▁예상
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=260 size=1500 all=214818 active=15671 piece=▁쓸
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=260 min_freq=27
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=256 size=1520 all=215583 active=11474 piece=▁여전
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=252 size=1540 all=216148 active=12039 piece=▁잃
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=247 size=1560 all=217141 active=13032 piece=▁w
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=244 size=1580 all=217666 active=13557 piece=저히
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=240 size=1600 all=218366 active=14257 piece=▁맨
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=240 min_freq=26
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=235 size=1620 all=219336 active=11855 piece=▁누구
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=232 size=1640 all=220181 active=12700 piece=▁된다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=229 size=1660 all=220913 active=13432 piece=▁돈이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=226 size=1680 all=221477 active=13996 piece=거다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=223 size=1700 all=222503 active=15022 piece=▁유치한
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=223 min_freq=25
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=220 size=1720 all=223783 active=12386 piece=▁보았
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=218 size=1740 all=224334 active=12937 piece=▁리메이크
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=216 size=1760 all=225168 active=13771 piece=▁지금봐도
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=213 size=1780 all=225595 active=14198 piece=▁짱짱
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=209 size=1800 all=226546 active=15149 piece=▁찌
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=209 min_freq=24
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=207 size=1820 all=227199 active=11953 piece=▁천재
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=203 size=1840 all=228019 active=12773 piece=▁못보
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=200 size=1860 all=228633 active=13387 piece=평가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=198 size=1880 all=229349 active=14103 piece=▁반전이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=195 size=1900 all=230094 active=14848 piece=▁안보
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=195 min_freq=24
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=192 size=1920 all=230627 active=11995 piece=그래
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=189 size=1940 all=231556 active=12924 piece=신이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=187 size=1960 all=232561 active=13928 piece=▁돌려
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=184 size=1980 all=233221 active=14588 piece=▁그랬
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=182 size=2000 all=233829 active=15196 piece=▁원래
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=182 min_freq=23
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=180 size=2020 all=234604 active=12452 piece=▁없을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=178 size=2040 all=235210 active=13058 piece=움이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=175 size=2060 all=235933 active=13781 piece=어울
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=174 size=2080 all=236502 active=14350 piece=기엔
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=172 size=2100 all=237185 active=15033 piece=발이
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=172 min_freq=22
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=171 size=2120 all=237812 active=12448 piece=▁스케
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=170 size=2140 all=238745 active=13381 piece=는영화
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=168 size=2160 all=239559 active=14195 piece=▁인정
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=166 size=2180 all=240169 active=14805 piece=▁아마
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=164 size=2200 all=241164 active=15799 piece=쵝오
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=164 min_freq=22
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=163 size=2220 all=241988 active=12854 piece=▁마음을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=161 size=2240 all=242371 active=13237 piece=구려
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=160 size=2260 all=243162 active=14028 piece=재밌어요
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=158 size=2280 all=244016 active=14882 piece=었나
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=157 size=2300 all=244646 active=15512 piece=었네요
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=157 min_freq=21
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=155 size=2320 all=245146 active=12675 piece=▁조폭
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=154 size=2340 all=245786 active=13315 piece=▁봤었는데
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=152 size=2360 all=246266 active=13795 piece=영화에
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=150 size=2380 all=247074 active=14602 piece=▁미스
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=149 size=2400 all=247664 active=15191 piece=▁사극
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=149 min_freq=21
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=148 size=2420 all=248493 active=13169 piece=▁11
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=146 size=2440 all=249098 active=13774 piece=나올
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=145 size=2460 all=249718 active=14394 piece=▁정치
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=143 size=2480 all=250286 active=14962 piece=▁v
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=142 size=2500 all=250766 active=15442 piece=▁쇼
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=142 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=141 size=2520 all=251571 active=13311 piece=과는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=140 size=2540 all=252687 active=14427 piece=화가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=139 size=2560 all=253274 active=15014 piece=▁물론
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=138 size=2580 all=253872 active=15612 piece=▁놀랍
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=137 size=2600 all=254576 active=16316 piece=보이
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=137 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=136 size=2620 all=255405 active=13471 piece=해주
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=135 size=2640 all=255994 active=14060 piece=▁있나
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=133 size=2660 all=256504 active=14570 piece=성애
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=133 size=2680 all=257051 active=15117 piece=▁스토리와
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=131 size=2700 all=257608 active=15674 piece=극장
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=131 min_freq=19
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=130 size=2720 all=258495 active=13677 piece=▁벌써
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=129 size=2740 all=259371 active=14553 piece=▁유치하다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=128 size=2760 all=260042 active=15224 piece=▁부분이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=127 size=2780 all=260436 active=15618 piece=사람이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=126 size=2800 all=261020 active=16202 piece=▁마이클
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=126 min_freq=19
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=125 size=2820 all=261517 active=13527 piece=하지않
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=124 size=2840 all=262044 active=14054 piece=▁단연
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=123 size=2860 all=262548 active=14558 piece=웠음
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=122 size=2880 all=263242 active=15252 piece=▁거짓
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=121 size=2900 all=263801 active=15811 piece=▁악역
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=121 min_freq=18
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=120 size=2920 all=264333 active=13690 piece=지말
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=119 size=2940 all=264661 active=14018 piece=ll
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=118 size=2960 all=265081 active=14438 piece=▁밥
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=118 size=2980 all=265716 active=15073 piece=▁시간을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=117 size=3000 all=266486 active=15843 piece=▁해리
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=117 min_freq=18
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=116 size=3020 all=267141 active=13973 piece=하다니
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=115 size=3040 all=267717 active=14549 piece=▁눈물을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=114 size=3060 all=268025 active=14857 piece=▁둘다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=113 size=3080 all=268563 active=15395 piece=▁내려
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=112 size=3100 all=268781 active=15613 piece=가능
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=112 min_freq=18
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=111 size=3120 all=269282 active=13892 piece=▁탁
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=110 size=3140 all=269873 active=14483 piece=▁퇴
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=109 size=3160 all=270626 active=15236 piece=▁센
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=108 size=3180 all=271313 active=15923 piece=▁미모
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=107 size=3200 all=271794 active=16404 piece=▁빼고는
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=107 min_freq=17
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=106 size=3220 all=272128 active=13924 piece=▁크게
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=105 size=3240 all=272555 active=14351 piece=▁같아
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=104 size=3260 all=273171 active=14967 piece=▁가진
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=103 size=3280 all=273599 active=15395 piece=▁뜻
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=102 size=3300 all=274085 active=15881 piece=▁개뿔
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=102 min_freq=17
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=101 size=3320 all=274506 active=14123 piece=연출
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=101 size=3340 all=275094 active=14711 piece=▁떠나서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=100 size=3360 all=275730 active=15347 piece=▁능력
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=100 size=3380 all=276144 active=15761 piece=▁재밌다고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=99 size=3400 all=276652 active=16269 piece=▁편견
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=99 min_freq=17
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=98 size=3420 all=277303 active=14468 piece=▁먹고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=98 size=3440 all=277650 active=14815 piece=▁카리스마
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=97 size=3460 all=278270 active=15435 piece=▁바꿔
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=97 size=3480 all=278639 active=15804 piece=▁진부하고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=96 size=3500 all=279138 active=16303 piece=▁그당시
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=96 min_freq=16
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=95 size=3520 all=279512 active=14318 piece=어용
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=95 size=3540 all=280003 active=14809 piece=▁비디오로
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=94 size=3560 all=280432 active=15238 piece=없네요
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=93 size=3580 all=280832 active=15638 piece=하셨
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=93 size=3600 all=281335 active=16141 piece=더라구요
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=93 min_freq=16
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=92 size=3620 all=281878 active=14559 piece=▁제니
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=91 size=3640 all=282126 active=14807 piece=년의
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=91 size=3660 all=282608 active=15289 piece=▁한심한
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=90 size=3680 all=283049 active=15730 piece=▁반성
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=89 size=3700 all=283356 active=16037 piece=누나
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=89 min_freq=16
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=89 size=3720 all=284061 active=14808 piece=▁가슴에
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=88 size=3740 all=284560 active=15307 piece=▁만한
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=88 size=3760 all=284839 active=15586 piece=▁클레멘타
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=87 size=3780 all=285353 active=16100 piece=▁허세
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=86 size=3800 all=285805 active=16552 piece=과서
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=86 min_freq=16
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=86 size=3820 all=286327 active=14790 piece=▁투자
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=85 size=3840 all=286711 active=15174 piece=빼고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=85 size=3860 all=287146 active=15609 piece=▁하나의
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=84 size=3880 all=287644 active=16107 piece=했나
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=84 size=3900 all=288090 active=16553 piece=▁반전은
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=84 min_freq=15
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=83 size=3920 all=288473 active=14784 piece=장난
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=83 size=3940 all=288927 active=15238 piece=▁가치가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=82 size=3960 all=289086 active=15397 piece=가네
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=82 size=3980 all=289760 active=16071 piece=▁일부
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=82 size=4000 all=289976 active=16287 piece=▁남자주인공
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=82 min_freq=15
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=81 size=4020 all=290425 active=14931 piece=▁어두
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=81 size=4040 all=290795 active=15301 piece=▁볼만했다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=80 size=4060 all=291465 active=15971 piece=▁못봐
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=80 size=4080 all=291806 active=16312 piece=▁한편의
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=79 size=4100 all=292455 active=16961 piece=치곤
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=79 min_freq=15
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=79 size=4120 all=292885 active=15012 piece=▁만들면
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=78 size=4140 all=293199 active=15326 piece=번은
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=78 size=4160 all=293754 active=15881 piece=지않고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=77 size=4180 all=293905 active=16032 piece=▁깡
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=77 size=4200 all=294393 active=16520 piece=▁조선
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=77 min_freq=15
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=76 size=4220 all=294892 active=15192 piece=러스
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=76 size=4240 all=295527 active=15827 piece=▁충실
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=76 size=4260 all=295840 active=16140 piece=▁참신한
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=75 size=4280 all=296299 active=16599 piece=▁새끼
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=75 size=4300 all=296661 active=16961 piece=▁이소룡
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=75 min_freq=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=74 size=4320 all=297134 active=15285 piece=▁깨달
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=74 size=4340 all=297511 active=15662 piece=▁봐야지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=73 size=4360 all=297790 active=15941 piece=때매
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=73 size=4380 all=298349 active=16500 piece=▁장진
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=73 size=4400 all=298621 active=16772 piece=▁최고봉
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=73 min_freq=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=72 size=4420 all=298988 active=15284 piece=우고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=72 size=4440 all=299323 active=15619 piece=▁스릴도
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=72 size=4460 all=299501 active=15797 piece=▁감동적이네요
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=71 size=4480 all=300042 active=16338 piece=▁떠올
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=71 size=4500 all=300357 active=16653 piece=▁첫사랑
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=71 min_freq=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=70 size=4520 all=300837 active=15484 piece=테일
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=70 size=4540 all=301104 active=15751 piece=▁헤어
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=70 size=4560 all=301488 active=16135 piece=▁하나로
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=69 size=4580 all=301867 active=16514 piece=사건
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=69 size=4600 all=302412 active=17059 piece=▁중독
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=69 min_freq=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=69 size=4620 all=302886 active=15567 piece=▁다양한
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=69 size=4640 all=303019 active=15700 piece=▁웃으면서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=68 size=4660 all=303473 active=16154 piece=▁오우
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=68 size=4680 all=303732 active=16413 piece=▁생각난다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=67 size=4700 all=304173 active=16854 piece=▁개념
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=67 min_freq=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=67 size=4720 all=304518 active=15531 piece=▁알겠다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=66 size=4740 all=304792 active=15805 piece=개그
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=66 size=4760 all=305320 active=16333 piece=▁유럽
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=66 size=4780 all=305649 active=16662 piece=▁없었음
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=4800 all=305765 active=16778 piece=▁숀
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=65 min_freq=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=4820 all=306410 active=15926 piece=▁망친
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=4840 all=306865 active=16381 piece=▁내용에
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=4860 all=306960 active=16476 piece=▁최고최고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=64 size=4880 all=307572 active=17088 piece=▁기준
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=64 size=4900 all=307912 active=17428 piece=▁느꼈다
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=64 min_freq=13
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=64 size=4920 all=308007 active=15489 piece=▁아름답게
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=63 size=4940 all=308531 active=16013 piece=아노
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=63 size=4960 all=308937 active=16419 piece=▁싶지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=63 size=4980 all=309220 active=16702 piece=▁사이코
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=5000 all=309566 active=17048 piece=문화
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=62 min_freq=13
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=5020 all=310333 active=16195 piece=▁꿈꾸
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=5040 all=310535 active=16397 piece=▁액션과
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=5060 all=310743 active=16605 piece=▁죠
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=5080 all=311403 active=17265 piece=▁25
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=5100 all=311660 active=17521 piece=▁추격
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=61 min_freq=13
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=5120 all=311977 active=15886 piece=▁아진짜
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=5140 all=312191 active=16100 piece=▁잉
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=5160 all=312968 active=16877 piece=해선
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=5180 all=313172 active=17081 piece=▁오유
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=5200 all=313519 active=17428
# -rw-r--r-- 1 root root 373120 Nov 28 04:52 korean_spm.model
# -rw-r--r-- 1 root root 118346 Nov 28 04:52 korean_spm.vocab

# %%
spp = spm.SentencePieceProcessor()
spp.Load('korean_spm.model')

ratings_X, word_index, index_word = sp_tokenize(spp, ratings['document'])

train_X = ratings_X[: train_end_idx+1]
test_X = ratings_X[train_end_idx+1: ]

train_y = np.array(ratings['label'][: train_end_idx+1], dtype='float32')
test_y = np.array(ratings['label'][train_end_idx+1: ], dtype='float32')

X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size=tsize(train_X))


# point
word_vector_dim = 2 ** 6
units = int(word_vector_dim / 2)

model = model_maker(vocab_size, word_vector_dim, units)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
              
epochs = 2 ** 4

early_stop = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

history = model.fit(X_train,
                    y_train,
                    epochs=epochs,
                    batch_size=2**10, # point
                    validation_data=(X_val, y_val),
                    verbose=1,
                   callbacks=[early_stop])
# Out:
# Epoch 1/16
# 119/119 [==============================] - 5s 20ms/step - loss: 0.5435 - accuracy: 0.7315 - val_loss: 0.3783 - val_accuracy: 0.8455
# Epoch 2/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3569 - accuracy: 0.8531 - val_loss: 0.3466 - val_accuracy: 0.8491
# Epoch 3/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3239 - accuracy: 0.8656 - val_loss: 0.3403 - val_accuracy: 0.8505
# Epoch 4/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3091 - accuracy: 0.8706 - val_loss: 0.3367 - val_accuracy: 0.8554
# Epoch 5/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2944 - accuracy: 0.8772 - val_loss: 0.3445 - val_accuracy: 0.8537
# Epoch 6/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2817 - accuracy: 0.8814 - val_loss: 0.3399 - val_accuracy: 0.8564
# Epoch 7/16
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2676 - accuracy: 0.8870 - val_loss: 0.3519 - val_accuracy: 0.8552
# Epoch 00007: early stopping

# %%
history_plot(history)

# %%
result = model.evaluate(test_X,  test_y, verbose=1)
# Out:
# 1322/1322 [==============================] - 5s 4ms/step - loss: 0.3628 - accuracy: 0.8485

# %%
print('unigram의 accuracy: 0.8454')
print('bpe의 accuracy: 0.8485')
# Out:
# unigram의 accuracy: 0.8454
# bpe의 accuracy: 0.8485

# %% [markdown]
# 두 토크나이저의 성능 차이가 별로 나지 않았다.
# 그래도 그나마 성능이 나은 건 bpe다.
# 둘 다 딥러닝에 최적화된 모델이다 보니 쉽게 80% 이상의 성능을 보여준다.

# %% [markdown]
# # 9. 회고하기

# %% [markdown]
# ## 9.1. 이번 프로젝트에서 어려웠던 점

# %% [markdown]
# 센텐스피스 모델 세팅을 하는데 일반적으로 인스턴스를 생성할 때 퍼래머더를 넣는 방식이 아닌
# 라이브러리로 바로 학습을 시키고 파일로 저장시킨 후 파일을 불러오는 방식이라서
# 이런 시스템을 받아들이는데 시간이 걸렸다.

# %% [markdown]
# ## 9.2. 프로젝트를 진행하면서 알아낸 점 혹은 아직 모호한 점

# %% [markdown]
# 형태소 분석기가 짱인 줄 알았는데 딥러닝에 최적화된, 그것도 최근
# pretrained model들이 거의 대부분 채용하는 사실상 표준의 역할을 하는
# SentencePiece tokenizer가 있다는 사실에 뒤통수를 얻어맞은 느낌이다.
# 그래도 이번에 좋은 거 배웠으니 앞으로 잘 써먹어야겠다.
#
# 하지만 아직 모호한 점도 있었는데 unigram과 bpe의 정확한 차이점을 모르겠다는 것이다.
# 이 부분은 아직 배울 기회가 많을 것 같아서 이번에는 패스했다.

# %% [markdown]
# ## 9.3. 루브릭 평가 지표를 맞추기 위해 시도한 것들

# %% [markdown]
# 저번에 했던 엑스플러레이션 8번은 참고하면 코퍼스 분석, 전처리 등은 쉽게 할 수 있었고
# sentencepiece는 주어진 코드를 참고해서 진행할 수 있었다.
#
# 이번에도 정확도를 조금이라도 더 올리기 위해 RNN 모델을 만져봤는데
# Bidirectional라는 양박향 LSTM이 있다는 것을 알게되어서 사용해보았고
# BatchNormalization은 Loss, Accuracy가 튀는 문제가 있어서
# 대신 Dropout만 사용했다. 왜 값이 튀는지는 파악하지 못했다.
#
# unigram외에도 bpe 모델도 사용해보았다.
# bpe 모델에 vocab_size를 2 ** 14(10000 이상) 지정해줬을 때
# 진행이 안되었다. 이게 버그인건지 뭔지 도무지 모르겠다.

# %% [markdown]
# ## 9.4. 만약에 루브릭 평가 관련 지표를 달성 하지 못했을 때, 이유에 관한 추정

# %% [markdown]
# 다른 토크나이저 모델로도 진행하는 것이 조금 버거울 수는 있을 것 같다.

# %% [markdown]
# ## 9.5. 자기 다짐

# %% [markdown]
# 이번 프로젝트를 통해 lstm 모델을 더 잘 쌓는 방법을 알아냈다.
# 여태까지 모델 레이어를 쌓는데 3일 정도 걸렸었는데
# 이제는 시간 단축을 좀 할 수 있을 것 같다.
#
# 시간 관리를 참 못하는 성격이라 게임도 못하고 친구도 안만나고
# 담배도 안피고 술도 안마시고 사는데도 프로젝트가 점점 밀리고 있다.
# 소장님이 말씀하셨던 것처럼 "한 번에 여러 가지", "중요한 것을 우선"
# 명언을 항상 생각하며 살아야겠다.
